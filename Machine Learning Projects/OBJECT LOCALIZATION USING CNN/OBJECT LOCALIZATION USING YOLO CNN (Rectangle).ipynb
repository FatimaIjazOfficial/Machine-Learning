# %% [markdown]
# # OBJECT LOCALIZATION USING YOLO CNN (Rectangle)

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import numpy as np  # numerical operations
import cv2  # image processing
import matplotlib.pyplot as plt  # visualization
from sklearn.model_selection import train_test_split  # dataset split
from tensorflow.keras.callbacks import EarlyStopping  # early stopping

# %%
from tensorflow.keras.models import Sequential  # CNN model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense  # layers

# %% [markdown]
# ## CONFIGURATION

# %%
Image_Size = 256  # input image size
sample = 1000

# %% [markdown]
# ## DATASET

# %% [markdown]
# ### CREATE

# %%
def create_dataset(samples=sample):

    images = []
    labels = []

    for _ in range(samples):

        img = np.zeros((Image_Size, Image_Size, 3),dtype=np.uint8)

        w = np.random.randint(20,50)
        h = np.random.randint(20,50)
        x = np.random.randint(5, Image_Size-w-5)
        y = np.random.randint(5, Image_Size-h-5)

        cv2.rectangle(img, (x, y), (x+w, y+h), (255,255,255), -1)

        x_center = (x + w/2) / Image_Size
        y_center = (y + h/2) / Image_Size
        width = w / Image_Size
        height = h / Image_Size

        labels.append([x_center, y_center, width, height])
        images.append(img)

    return np.array(images), np.array(labels)

# %% [markdown]
# ### GENERATE

# %%
X, y = create_dataset(sample)

print("=" * 60)
print("DATASET CREATED")
print("=" * 60)

print("Images Shape :", X.shape)
print("Labels/Masks :", y.shape)
# Out:
# ============================================================
# DATASET CREATED
# ============================================================
# Images Shape : (1000, 256, 256, 3)
# Labels/Masks : (1000, 4)

# %% [markdown]
# ### NORMALIZATION

# %%
X = X.astype("float32") / 255.0

# %% [markdown]
# ### TRAIN TEST SPLIT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, shuffle=True)
print("=" * 60)
print("TRAIN / TEST SPLIT")
print("=" * 60)
print("Training Images :", X_train.shape)
print("Testing Images  :", X_test.shape)
print("Training Labels :", y_train.shape)
print("Testing Labels  :", y_test.shape)
# Out:
# ============================================================
# TRAIN / TEST SPLIT
# ============================================================
# Training Images : (800, 256, 256, 3)
# Testing Images  : (200, 256, 256, 3)
# Training Labels : (800, 4)
# Testing Labels  : (200, 4)

# %% [markdown]
# ## MODEL

# %% [markdown]
# ### BUILD

# %%
model = Sequential([

    Input(shape=(Image_Size, Image_Size, 3)),  # input layer

    Conv2D(16, (3,3), padding="same", activation="relu"),  # feature extractor 1
    MaxPooling2D(),  # downsample

    Conv2D(16, (3,3), padding="same", activation="relu"),  # feature extractor 2
    MaxPooling2D(),  # downsample

    Conv2D(32, (3,3), padding="same", activation="relu"),  # feature extractor 3
    MaxPooling2D(),  # downsample

    Conv2D(64, (3,3), padding="same", activation="relu"),  # feature extractor 4
    MaxPooling2D(),  # downsample

    Conv2D(128, (3,3), padding="same", activation="relu"),  # feature extractor 5
    MaxPooling2D(),  # downsample

    Flatten(),  # flatten features

    Dense(256, activation="relu"),
    Dense(128, activation="relu"),
    Dense(4, activation="sigmoid")  # output bounding box
])

# %% [markdown]
# ### SUMMARY

# %%
print("="*60)
print("MODEL SUMMARY")
print("="*60)

model.summary()
# Out:
# ============================================================
# MODEL SUMMARY
# ============================================================
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 128, 128, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 128, 128, 16)   │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     2,097,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,230,580 (8.51 MB)
#  Trainable params: 2,230,580 (8.51 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### COMPILE

# %%
model.compile(
    optimizer="adam",
    loss="mse"
)

# %% [markdown]
# ### EARLY STOPPING

# %%
early_stop = EarlyStopping(
    monitor="val_loss",  # monitor validation loss
    patience=3,  # stop if no improvement
    restore_best_weights=True  # keep best model
)

# %% [markdown]
# ### TRAIN

# %%
history = model.fit(
    X_train, y_train,
    validation_split=0.20,
    epochs=20,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - loss: 0.0160 - val_loss: 0.0024
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - loss: 8.7865e-04 - val_loss: 8.0902e-04
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - loss: 7.0024e-04 - val_loss: 9.8289e-04
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - loss: 6.0229e-04 - val_loss: 5.7711e-04
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 4.6520e-04 - val_loss: 4.7786e-04
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 40s 991ms/step - loss: 3.7458e-04 - val_loss: 4.3653e-04
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 2.7936e-04 - val_loss: 3.8307e-04
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 1.9976e-04 - val_loss: 2.8634e-04
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 1.3159e-04 - val_loss: 1.8081e-04
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 8.4802e-05 - val_loss: 1.4358e-04
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 50s 1s/step - loss: 5.6238e-05 - val_loss: 1.1987e-04
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - loss: 4.4788e-05 - val_loss: 1.0364e-04
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 3.3489e-05 - val_loss: 9.7242e-05
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 3.2621e-05 - val_loss: 9.3951e-05
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 2.8239e-05 - val_loss: 8.5449e-05
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - loss: 2.8621e-05 - val_loss: 9.0868e-05
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - loss: 2.6706e-05 - val_loss: 8.5467e-05
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 2.8108e-05 - val_loss: 9.2241e-05

# %% [markdown]
# ## LOSS PLOT

# %%
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'], label="Training Loss")  # training loss
plt.plot(history.history['val_loss'], label="Validation Loss")  # validation loss
plt.title("Training vs Validation Loss")  # title
plt.xlabel("Epoch")  # x-axis
plt.ylabel("Loss")  # y-axis
plt.title("Training vs Validation Loss")
plt.legend()  # legend
plt.grid(True)
plt.show()  # display graph

# %% [markdown]
# ## IoU FUNCTION

# %%
def IoU(box1, box2):

    x1, y1, w1, h1 = box1
    x2, y2, w2, h2 = box2

    x1_min = x1 - w1 / 2
    x1_max = x1 + w1 / 2
    y1_min = y1 - h1 / 2
    y1_max = y1 + h1 / 2

    x2_min = x2 - w2 / 2
    x2_max = x2 + w2 / 2
    y2_min = y2 - h2 / 2
    y2_max = y2 + h2 / 2

    inter_xmin = max(x1_min, x2_min)
    inter_ymin = max(y1_min, y2_min)
    inter_xmax = min(x1_max, x2_max)
    inter_ymax = min(y1_max, y2_max)

    inter_area = max(0,inter_xmax - inter_xmin) * max(0,inter_ymax - inter_ymin)
    union = (w1*h1) + (w2*h2) - inter_area

    return inter_area / (union + 1e-6)

# %% [markdown]
# ## VISUALIZATION (TRUE VS PREDICTED)

# %%
def draw_box(img, box, color):

    x, y, w, h = box

    x *= Image_Size
    y *= Image_Size
    w *= Image_Size
    h *= Image_Size

    x1 = int(x - w/2)
    y1 = int(y - h/2)
    x2 = int(x + w/2)
    y2 = int(y + h/2)

    cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)

# %%
preds = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 510ms/step

# %%
plt.figure(figsize=(20,20))

for i in range(min(len(X_test),20)):

    img = (X_test[i] * 255).astype(np.uint8).copy()

    # Yolo
    iou = IoU(preds[i], y_test[i])
    draw_box(img, y_test[i], (255,0,255))

    if iou >= 0.80:
        pred_color = (0,255,0)
        status = "EXCELLENT"
    elif iou >= 0.60:
        pred_color = (255,0,0)
        status = "GOOD"
    else:
        pred_color = (0,0,255)
        status = "WEAK"

    # Yolo
    draw_box(img, preds[i], pred_color)

    plt.subplot(10,10,i+1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(f"S{i+1}\n{status}\nIoU={iou:.2f}", fontsize=8)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## REPORT

# %%
ious = []

# %%
for i in range(len(preds)):
    ious.append(IoU(preds[i], y_test[i]))

# %%
excellent = 0
good = 0
weak = 0

for iou in ious:
    if iou >= 0.80:
        excellent += 1
    elif iou >= 0.60:
        good += 1
    else:
        weak += 1

print("="*80)

# Yolo
print("LOCALIZATION REPORT")

print("="*80)

for i in range(len(preds)):
    iou = ious[i]
    if iou >= 0.80:
        status = "✔ EXCELLENT"
    elif iou >= 0.60:
        status = "➜ GOOD"
    else:
        status = "✖ WEAK"
    print(f"\nSample {i+1}")
    print("-"*60)

    # Yolo
    print("True Box      :", np.round(y_test[i],3))
    print("Predicted Box :", np.round(preds[i],3))

    print("IoU :", round(iou,3))
    print("Status :", status)
# Out:
# ================================================================================
# LOCALIZATION REPORT
# ================================================================================
#
# Sample 1
# ------------------------------------------------------------
# True Box      : [0.758 0.146 0.117 0.184]
# Predicted Box : [0.749 0.151 0.124 0.166]
# IoU : 0.793
# Status : ➜ GOOD
#
# Sample 2
# ------------------------------------------------------------
# True Box      : [0.885 0.188 0.137 0.109]
# Predicted Box : [0.879 0.196 0.137 0.108]
# IoU : 0.797
# Status : ➜ GOOD
#
# Sample 3
# ------------------------------------------------------------
# True Box      : [0.51  0.264 0.145 0.137]
# Predicted Box : [0.512 0.253 0.151 0.134]
# IoU : 0.821
# Status : ✔ EXCELLENT
#
# Sample 4
# ------------------------------------------------------------
# True Box      : [0.527 0.412 0.18  0.168]
# Predicted Box : [0.53  0.403 0.171 0.166]
# IoU : 0.853
# Status : ✔ EXCELLENT
#
# Sample 5
# ------------------------------------------------------------
# True Box      : [0.203 0.516 0.164 0.078]
# Predicted Box : [0.186 0.516 0.166 0.085]
# IoU : 0.75
# Status : ➜ GOOD
#
# Sample 6
# ------------------------------------------------------------
# True Box      : [0.357 0.775 0.184 0.09 ]
# Predicted Box : [0.359 0.781 0.177 0.089]
# IoU : 0.844
# Status : ✔ EXCELLENT
#
# Sample 7
# ------------------------------------------------------------
# True Box      : [0.381 0.658 0.121 0.152]
# Predicted Box : [0.378 0.658 0.121 0.138]
# IoU : 0.87
# Status : ✔ EXCELLENT
#
# Sample 8
# ------------------------------------------------------------
# True Box      : [0.312 0.85  0.117 0.113]
# Predicted Box : [0.31  0.851 0.117 0.112]
# IoU : 0.936
# Status : ✔ EXCELLENT
#
# Sample 9
# ------------------------------------------------------------
# True Box      : [0.545 0.301 0.129 0.078]
# Predicted Box : [0.55  0.307 0.134 0.081]
# IoU : 0.799
# Status : ➜ GOOD
#
# Sample 10
# ------------------------------------------------------------
# True Box      : [0.422 0.166 0.086 0.145]
# Predicted Box : [0.412 0.164 0.084 0.133]
# IoU : 0.736
# Status : ➜ GOOD
#
# Sample 11
# ------------------------------------------------------------
# True Box      : [0.822 0.85  0.137 0.168]
# Predicted Box : [0.818 0.853 0.131 0.161]
# IoU : 0.9
# Status : ✔ EXCELLENT
#
# Sample 12
# ------------------------------------------------------------
# True Box      : [0.447 0.088 0.152 0.113]
# Predicted Box : [0.449 0.096 0.152 0.108]
# IoU : 0.839
# Status : ✔ EXCELLENT
#
# Sample 13
# ------------------------------------------------------------
# True Box      : [0.59  0.684 0.156 0.18 ]
# Predicted Box : [0.594 0.687 0.162 0.169]
# IoU : 0.902
# Status : ✔ EXCELLENT
#
# Sample 14
# ------------------------------------------------------------
# True Box      : [0.789 0.875 0.172 0.078]
# Predicted Box : [0.791 0.886 0.155 0.091]
# IoU : 0.703
# Status : ➜ GOOD
#
# Sample 15
# ------------------------------------------------------------
# True Box      : [0.156 0.693 0.172 0.137]
# Predicted Box : [0.159 0.699 0.178 0.125]
# IoU : 0.885
# Status : ✔ EXCELLENT
#
# Sample 16
# ------------------------------------------------------------
# True Box      : [0.338 0.379 0.113 0.078]
# Predicted Box : [0.331 0.375 0.108 0.079]
# IoU : 0.804
# Status : ✔ EXCELLENT
#
# Sample 17
# ------------------------------------------------------------
# True Box      : [0.141 0.768 0.172 0.121]
# Predicted Box : [0.132 0.778 0.156 0.113]
# IoU : 0.761
# Status : ➜ GOOD
#
# Sample 18
# ------------------------------------------------------------
# True Box      : [0.1   0.711 0.082 0.188]
# Predicted Box : [0.1   0.715 0.107 0.132]
# IoU : 0.579
# Status : ✖ WEAK
#
# Sample 19
# ------------------------------------------------------------
# True Box      : [0.141 0.469 0.18  0.164]
# Predicted Box : [0.152 0.467 0.165 0.151]
# IoU : 0.806
# Status : ✔ EXCELLENT
#
# Sample 20
# ------------------------------------------------------------
# True Box      : [0.256 0.406 0.184 0.156]
# Predicted Box : [0.253 0.407 0.178 0.156]
# IoU : 0.964
# Status : ✔ EXCELLENT
#
# Sample 21
# ------------------------------------------------------------
# True Box      : [0.361 0.152 0.152 0.172]
# Predicted Box : [0.363 0.159 0.148 0.18 ]
# IoU : 0.903
# Status : ✔ EXCELLENT
#
# Sample 22
# ------------------------------------------------------------
# True Box      : [0.871 0.531 0.188 0.148]
# Predicted Box : [0.866 0.532 0.175 0.144]
# IoU : 0.902
# Status : ✔ EXCELLENT
#
# Sample 23
# ------------------------------------------------------------
# True Box      : [0.662 0.32  0.113 0.109]
# Predicted Box : [0.649 0.323 0.107 0.113]
# IoU : 0.755
# Status : ➜ GOOD
#
# Sample 24
# ------------------------------------------------------------
# True Box      : [0.721 0.33  0.152 0.16 ]
# Predicted Box : [0.709 0.334 0.152 0.155]
# IoU : 0.821
# Status : ✔ EXCELLENT
#
# Sample 25
# ------------------------------------------------------------
# True Box      : [0.557 0.189 0.152 0.176]
# Predicted Box : [0.561 0.191 0.142 0.168]
# IoU : 0.892
# Status : ✔ EXCELLENT
#
# Sample 26
# ------------------------------------------------------------
# True Box      : [0.551 0.084 0.133 0.129]
# Predicted Box : [0.557 0.102 0.136 0.139]
# IoU : 0.706
# Status : ➜ GOOD
#
# Sample 27
# ------------------------------------------------------------
# True Box      : [0.879 0.406 0.102 0.109]
# Predicted Box : [0.879 0.414 0.1   0.106]
# IoU : 0.857
# Status : ✔ EXCELLENT
#
# Sample 28
# ------------------------------------------------------------
# True Box      : [0.605 0.627 0.125 0.145]
# Predicted Box : [0.606 0.626 0.127 0.141]
# IoU : 0.963
# Status : ✔ EXCELLENT
#
# Sample 29
# ------------------------------------------------------------
# True Box      : [0.25  0.734 0.117 0.102]
# Predicted Box : [0.251 0.736 0.116 0.099]
# IoU : 0.951
# Status : ✔ EXCELLENT
#
# Sample 30
# ------------------------------------------------------------
# True Box      : [0.895 0.352 0.164 0.117]
# Predicted Box : [0.869 0.362 0.159 0.116]
# IoU : 0.624
# Status : ➜ GOOD
#
# Sample 31
# ------------------------------------------------------------
# True Box      : [0.674 0.299 0.168 0.16 ]
# Predicted Box : [0.669 0.301 0.16  0.154]
# IoU : 0.91
# Status : ✔ EXCELLENT
#
# Sample 32
# ------------------------------------------------------------
# True Box      : [0.549 0.219 0.168 0.18 ]
# Predicted Box : [0.551 0.217 0.16  0.17 ]
# IoU : 0.903
# Status : ✔ EXCELLENT
#
# Sample 33
# ------------------------------------------------------------
# True Box      : [0.855 0.391 0.133 0.102]
# Predicted Box : [0.859 0.392 0.129 0.094]
# IoU : 0.878
# Status : ✔ EXCELLENT
#
# Sample 34
# ------------------------------------------------------------
# True Box      : [0.295 0.408 0.113 0.184]
# Predicted Box : [0.291 0.405 0.106 0.159]
# IoU : 0.801
# Status : ✔ EXCELLENT
#
# Sample 35
# ------------------------------------------------------------
# True Box      : [0.828 0.85  0.156 0.191]
# Predicted Box : [0.824 0.855 0.15  0.176]
# IoU : 0.868
# Status : ✔ EXCELLENT
#
# Sample 36
# ------------------------------------------------------------
# True Box      : [0.734 0.83  0.133 0.16 ]
# Predicted Box : [0.729 0.824 0.135 0.165]
# IoU : 0.857
# Status : ✔ EXCELLENT
#
# Sample 37
# ------------------------------------------------------------
# True Box      : [0.654 0.203 0.129 0.125]
# Predicted Box : [0.646 0.206 0.129 0.112]
# IoU : 0.79
# Status : ➜ GOOD
#
# Sample 38
# ------------------------------------------------------------
# True Box      : [0.232 0.209 0.113 0.105]
# Predicted Box : [0.235 0.208 0.111 0.11 ]
# IoU : 0.912
# Status : ✔ EXCELLENT
#
# Sample 39
# ------------------------------------------------------------
# True Box      : [0.402 0.783 0.078 0.184]
# Predicted Box : [0.398 0.779 0.098 0.172]
# IoU : 0.754
# Status : ➜ GOOD
#
# Sample 40
# ------------------------------------------------------------
# True Box      : [0.879 0.305 0.164 0.125]
# Predicted Box : [0.87  0.311 0.162 0.125]
# IoU : 0.821
# Status : ✔ EXCELLENT
#
# Sample 41
# ------------------------------------------------------------
# True Box      : [0.318 0.594 0.105 0.164]
# Predicted Box : [0.312 0.593 0.099 0.171]
# IoU : 0.848
# Status : ✔ EXCELLENT
#
# Sample 42
# ------------------------------------------------------------
# True Box      : [0.809 0.193 0.18  0.098]
# Predicted Box : [0.81  0.201 0.174 0.098]
# IoU : 0.826
# Status : ✔ EXCELLENT
#
# Sample 43
# ------------------------------------------------------------
# True Box      : [0.496 0.465 0.148 0.18 ]
# Predicted Box : [0.503 0.469 0.155 0.166]
# IoU : 0.85
# Status : ✔ EXCELLENT
#
# Sample 44
# ------------------------------------------------------------
# True Box      : [0.658 0.344 0.098 0.141]
# Predicted Box : [0.642 0.345 0.102 0.141]
# IoU : 0.715
# Status : ➜ GOOD
#
# Sample 45
# ------------------------------------------------------------
# True Box      : [0.617 0.713 0.141 0.105]
# Predicted Box : [0.619 0.723 0.135 0.104]
# IoU : 0.799
# Status : ➜ GOOD
#
# Sample 46
# ------------------------------------------------------------
# True Box      : [0.83  0.799 0.152 0.121]
# Predicted Box : [0.825 0.799 0.151 0.12 ]
# IoU : 0.927
# Status : ✔ EXCELLENT
#
# Sample 47
# ------------------------------------------------------------
# True Box      : [0.805 0.125 0.094 0.086]
# Predicted Box : [0.808 0.114 0.102 0.094]
# IoU : 0.714
# Status : ➜ GOOD
#
# Sample 48
# ------------------------------------------------------------
# True Box      : [0.715 0.57  0.172 0.141]
# Predicted Box : [0.709 0.569 0.177 0.139]
# IoU : 0.92
# Status : ✔ EXCELLENT
#
# Sample 49
# ------------------------------------------------------------
# True Box      : [0.076 0.887 0.082 0.117]
# Predicted Box : [0.101 0.882 0.105 0.127]
# IoU : 0.537
# Status : ✖ WEAK
#
# Sample 50
# ------------------------------------------------------------
# True Box      : [0.277 0.832 0.141 0.109]
# Predicted Box : [0.265 0.843 0.124 0.097]
# IoU : 0.674
# Status : ➜ GOOD
#
# Sample 51
# ------------------------------------------------------------
# True Box      : [0.625 0.633 0.172 0.078]
# Predicted Box : [0.617 0.627 0.172 0.085]
# IoU : 0.798
# Status : ➜ GOOD
#
# Sample 52
# ------------------------------------------------------------
# True Box      : [0.705 0.449 0.098 0.18 ]
# Predicted Box : [0.703 0.452 0.098 0.176]
# IoU : 0.928
# Status : ✔ EXCELLENT
#
# Sample 53
# ------------------------------------------------------------
# True Box      : [0.211 0.244 0.094 0.09 ]
# Predicted Box : [0.206 0.236 0.087 0.092]
# IoU : 0.754
# Status : ➜ GOOD
#
# Sample 54
# ------------------------------------------------------------
# True Box      : [0.654 0.898 0.137 0.086]
# Predicted Box : [0.651 0.905 0.142 0.1  ]
# IoU : 0.819
# Status : ✔ EXCELLENT
#
# Sample 55
# ------------------------------------------------------------
# True Box      : [0.654 0.404 0.09  0.16 ]
# Predicted Box : [0.638 0.401 0.102 0.15 ]
# IoU : 0.677
# Status : ➜ GOOD
#
# Sample 56
# ------------------------------------------------------------
# True Box      : [0.395 0.16  0.172 0.109]
# Predicted Box : [0.387 0.165 0.173 0.095]
# IoU : 0.797
# Status : ➜ GOOD
#
# Sample 57
# ------------------------------------------------------------
# True Box      : [0.402 0.191 0.078 0.188]
# Predicted Box : [0.398 0.194 0.093 0.165]
# IoU : 0.754
# Status : ➜ GOOD
#
# Sample 58
# ------------------------------------------------------------
# True Box      : [0.287 0.244 0.113 0.16 ]
# Predicted Box : [0.287 0.248 0.106 0.162]
# IoU : 0.901
# Status : ✔ EXCELLENT
#
# Sample 59
# ------------------------------------------------------------
# True Box      : [0.707 0.35  0.109 0.145]
# Predicted Box : [0.702 0.349 0.109 0.136]
# IoU : 0.859
# Status : ✔ EXCELLENT
#
# Sample 60
# ------------------------------------------------------------
# True Box      : [0.828 0.633 0.117 0.125]
# Predicted Box : [0.846 0.64  0.112 0.142]
# IoU : 0.657
# Status : ➜ GOOD
#
# Sample 61
# ------------------------------------------------------------
# True Box      : [0.695 0.252 0.133 0.137]
# Predicted Box : [0.689 0.252 0.136 0.13 ]
# IoU : 0.864
# Status : ✔ EXCELLENT
#
# Sample 62
# ------------------------------------------------------------
# True Box      : [0.125 0.406 0.094 0.117]
# Predicted Box : [0.12  0.404 0.099 0.114]
# IoU : 0.858
# Status : ✔ EXCELLENT
#
# Sample 63
# ------------------------------------------------------------
# True Box      : [0.176 0.918 0.133 0.109]
# Predicted Box : [0.192 0.915 0.126 0.103]
# IoU : 0.736
# Status : ➜ GOOD
#
# Sample 64
# ------------------------------------------------------------
# True Box      : [0.494 0.463 0.098 0.137]
# Predicted Box : [0.502 0.456 0.093 0.133]
# IoU : 0.777
# Status : ➜ GOOD
#
# Sample 65
# ------------------------------------------------------------
# True Box      : [0.775 0.637 0.191 0.18 ]
# Predicted Box : [0.771 0.649 0.188 0.172]
# IoU : 0.833
# Status : ✔ EXCELLENT
#
# Sample 66
# ------------------------------------------------------------
# True Box      : [0.527 0.854 0.125 0.152]
# Predicted Box : [0.527 0.862 0.125 0.157]
# IoU : 0.892
# Status : ✔ EXCELLENT
#
# Sample 67
# ------------------------------------------------------------
# True Box      : [0.879 0.811 0.109 0.152]
# Predicted Box : [0.88  0.817 0.104 0.152]
# IoU : 0.878
# Status : ✔ EXCELLENT
#
# Sample 68
# ------------------------------------------------------------
# True Box      : [0.33  0.234 0.137 0.141]
# Predicted Box : [0.328 0.233 0.142 0.138]
# IoU : 0.949
# Status : ✔ EXCELLENT
#
# Sample 69
# ------------------------------------------------------------
# True Box      : [0.328 0.908 0.094 0.121]
# Predicted Box : [0.324 0.897 0.122 0.124]
# IoU : 0.654
# Status : ➜ GOOD
#
# Sample 70
# ------------------------------------------------------------
# True Box      : [0.439 0.451 0.168 0.191]
# Predicted Box : [0.444 0.452 0.169 0.166]
# IoU : 0.821
# Status : ✔ EXCELLENT
#
# Sample 71
# ------------------------------------------------------------
# True Box      : [0.629 0.66  0.094 0.133]
# Predicted Box : [0.637 0.664 0.095 0.128]
# IoU : 0.785
# Status : ➜ GOOD
#
# Sample 72
# ------------------------------------------------------------
# True Box      : [0.881 0.312 0.152 0.133]
# Predicted Box : [0.876 0.315 0.151 0.129]
# IoU : 0.901
# Status : ✔ EXCELLENT
#
# Sample 73
# ------------------------------------------------------------
# True Box      : [0.49  0.898 0.145 0.078]
# Predicted Box : [0.487 0.898 0.122 0.096]
# IoU : 0.706
# Status : ➜ GOOD
#
# Sample 74
# ------------------------------------------------------------
# True Box      : [0.822 0.789 0.121 0.117]
# Predicted Box : [0.815 0.792 0.118 0.112]
# IoU : 0.844
# Status : ✔ EXCELLENT
#
# Sample 75
# ------------------------------------------------------------
# True Box      : [0.367 0.879 0.141 0.125]
# Predicted Box : [0.354 0.879 0.141 0.123]
# IoU : 0.809
# Status : ✔ EXCELLENT
#
# Sample 76
# ------------------------------------------------------------
# True Box      : [0.32  0.764 0.078 0.121]
# Predicted Box : [0.319 0.755 0.09  0.117]
# IoU : 0.761
# Status : ➜ GOOD
#
# Sample 77
# ------------------------------------------------------------
# True Box      : [0.201 0.266 0.191 0.141]
# Predicted Box : [0.196 0.266 0.173 0.139]
# IoU : 0.888
# Status : ✔ EXCELLENT
#
# Sample 78
# ------------------------------------------------------------
# True Box      : [0.379 0.365 0.125 0.176]
# Predicted Box : [0.371 0.358 0.114 0.169]
# IoU : 0.813
# Status : ✔ EXCELLENT
#
# Sample 79
# ------------------------------------------------------------
# True Box      : [0.914 0.75  0.102 0.164]
# Predicted Box : [0.905 0.744 0.109 0.139]
# IoU : 0.726
# Status : ➜ GOOD
#
# Sample 80
# ------------------------------------------------------------
# True Box      : [0.732 0.406 0.184 0.117]
# Predicted Box : [0.726 0.406 0.178 0.111]
# IoU : 0.883
# Status : ✔ EXCELLENT
#
# Sample 81
# ------------------------------------------------------------
# True Box      : [0.77  0.479 0.102 0.145]
# Predicted Box : [0.761 0.482 0.104 0.136]
# IoU : 0.805
# Status : ✔ EXCELLENT
#
# Sample 82
# ------------------------------------------------------------
# True Box      : [0.203 0.484 0.156 0.156]
# Predicted Box : [0.192 0.489 0.153 0.145]
# IoU : 0.81
# Status : ✔ EXCELLENT
#
# Sample 83
# ------------------------------------------------------------
# True Box      : [0.592 0.432 0.121 0.168]
# Predicted Box : [0.589 0.432 0.126 0.165]
# IoU : 0.948
# Status : ✔ EXCELLENT
#
# Sample 84
# ------------------------------------------------------------
# True Box      : [0.342 0.363 0.152 0.18 ]
# Predicted Box : [0.335 0.356 0.16  0.167]
# IoU : 0.855
# Status : ✔ EXCELLENT
#
# Sample 85
# ------------------------------------------------------------
# True Box      : [0.52  0.684 0.133 0.148]
# Predicted Box : [0.524 0.691 0.146 0.144]
# IoU : 0.828
# Status : ✔ EXCELLENT
#
# Sample 86
# ------------------------------------------------------------
# True Box      : [0.723 0.799 0.172 0.176]
# Predicted Box : [0.724 0.798 0.168 0.178]
# IoU : 0.964
# Status : ✔ EXCELLENT
#
# Sample 87
# ------------------------------------------------------------
# True Box      : [0.537 0.373 0.09  0.145]
# Predicted Box : [0.536 0.371 0.088 0.129]
# IoU : 0.872
# Status : ✔ EXCELLENT
#
# Sample 88
# ------------------------------------------------------------
# True Box      : [0.781 0.289 0.156 0.164]
# Predicted Box : [0.775 0.294 0.17  0.16 ]
# IoU : 0.866
# Status : ✔ EXCELLENT
#
# Sample 89
# ------------------------------------------------------------
# True Box      : [0.459 0.41  0.082 0.172]
# Predicted Box : [0.462 0.411 0.086 0.163]
# IoU : 0.879
# Status : ✔ EXCELLENT
#
# Sample 90
# ------------------------------------------------------------
# True Box      : [0.684 0.109 0.18  0.086]
# Predicted Box : [0.691 0.097 0.155 0.117]
# IoU : 0.656
# Status : ➜ GOOD
#
# Sample 91
# ------------------------------------------------------------
# True Box      : [0.826 0.697 0.145 0.16 ]
# Predicted Box : [0.819 0.699 0.142 0.172]
# IoU : 0.843
# Status : ✔ EXCELLENT
#
# Sample 92
# ------------------------------------------------------------
# True Box      : [0.738 0.844 0.164 0.117]
# Predicted Box : [0.736 0.846 0.157 0.122]
# IoU : 0.92
# Status : ✔ EXCELLENT
#
# Sample 93
# ------------------------------------------------------------
# True Box      : [0.221 0.607 0.098 0.121]
# Predicted Box : [0.215 0.611 0.1   0.115]
# IoU : 0.849
# Status : ✔ EXCELLENT
#
# Sample 94
# ------------------------------------------------------------
# True Box      : [0.721 0.412 0.082 0.145]
# Predicted Box : [0.717 0.416 0.103 0.138]
# IoU : 0.76
# Status : ➜ GOOD
#
# Sample 95
# ------------------------------------------------------------
# True Box      : [0.297 0.508 0.18  0.18 ]
# Predicted Box : [0.296 0.512 0.171 0.161]
# IoU : 0.852
# Status : ✔ EXCELLENT
#
# Sample 96
# ------------------------------------------------------------
# True Box      : [0.629 0.877 0.125 0.113]
# Predicted Box : [0.616 0.879 0.149 0.11 ]
# IoU : 0.804
# Status : ✔ EXCELLENT
#
# Sample 97
# ------------------------------------------------------------
# True Box      : [0.441 0.135 0.094 0.176]
# Predicted Box : [0.437 0.136 0.094 0.172]
# IoU : 0.885
# Status : ✔ EXCELLENT
#
# Sample 98
# ------------------------------------------------------------
# True Box      : [0.809 0.18  0.086 0.133]
# Predicted Box : [0.808 0.187 0.091 0.132]
# IoU : 0.854
# Status : ✔ EXCELLENT
#
# Sample 99
# ------------------------------------------------------------
# True Box      : [0.613 0.416 0.18  0.129]
# Predicted Box : [0.61  0.414 0.175 0.123]
# IoU : 0.921
# Status : ✔ EXCELLENT
#
# Sample 100
# ------------------------------------------------------------
# True Box      : [0.799 0.568 0.105 0.176]
# Predicted Box : [0.799 0.577 0.108 0.19 ]
# IoU : 0.886
# Status : ✔ EXCELLENT
#
# Sample 101
# ------------------------------------------------------------
# True Box      : [0.488 0.197 0.164 0.191]
# Predicted Box : [0.494 0.191 0.161 0.166]
# IoU : 0.811
# Status : ✔ EXCELLENT
#
# Sample 102
# ------------------------------------------------------------
# True Box      : [0.143 0.273 0.145 0.164]
# Predicted Box : [0.131 0.275 0.153 0.16 ]
# IoU : 0.832
# Status : ✔ EXCELLENT
#
# Sample 103
# ------------------------------------------------------------
# True Box      : [0.803 0.768 0.16  0.168]
# Predicted Box : [0.795 0.77  0.16  0.17 ]
# IoU : 0.876
# Status : ✔ EXCELLENT
#
# Sample 104
# ------------------------------------------------------------
# True Box      : [0.258 0.541 0.188 0.16 ]
# Predicted Box : [0.249 0.545 0.173 0.152]
# IoU : 0.856
# Status : ✔ EXCELLENT
#
# Sample 105
# ------------------------------------------------------------
# True Box      : [0.826 0.424 0.137 0.184]
# Predicted Box : [0.83  0.427 0.138 0.168]
# IoU : 0.865
# Status : ✔ EXCELLENT
#
# Sample 106
# ------------------------------------------------------------
# True Box      : [0.682 0.52  0.09  0.172]
# Predicted Box : [0.68  0.523 0.085 0.156]
# IoU : 0.862
# Status : ✔ EXCELLENT
#
# Sample 107
# ------------------------------------------------------------
# True Box      : [0.758 0.506 0.148 0.113]
# Predicted Box : [0.754 0.504 0.148 0.118]
# IoU : 0.909
# Status : ✔ EXCELLENT
#
# Sample 108
# ------------------------------------------------------------
# True Box      : [0.809 0.84  0.188 0.141]
# Predicted Box : [0.81  0.84  0.181 0.149]
# IoU : 0.91
# Status : ✔ EXCELLENT
#
# Sample 109
# ------------------------------------------------------------
# True Box      : [0.836 0.232 0.109 0.16 ]
# Predicted Box : [0.836 0.239 0.107 0.153]
# IoU : 0.904
# Status : ✔ EXCELLENT
#
# Sample 110
# ------------------------------------------------------------
# True Box      : [0.588 0.074 0.113 0.086]
# Predicted Box : [0.588 0.091 0.13  0.123]
# IoU : 0.612
# Status : ➜ GOOD
#
# Sample 111
# ------------------------------------------------------------
# True Box      : [0.402 0.711 0.094 0.125]
# Predicted Box : [0.401 0.705 0.097 0.117]
# IoU : 0.873
# Status : ✔ EXCELLENT
#
# Sample 112
# ------------------------------------------------------------
# True Box      : [0.27  0.338 0.172 0.129]
# Predicted Box : [0.268 0.336 0.16  0.125]
# IoU : 0.902
# Status : ✔ EXCELLENT
#
# Sample 113
# ------------------------------------------------------------
# True Box      : [0.582 0.322 0.164 0.184]
# Predicted Box : [0.581 0.322 0.17  0.155]
# IoU : 0.821
# Status : ✔ EXCELLENT
#
# Sample 114
# ------------------------------------------------------------
# True Box      : [0.205 0.725 0.129 0.168]
# Predicted Box : [0.2   0.734 0.122 0.149]
# IoU : 0.814
# Status : ✔ EXCELLENT
#
# Sample 115
# ------------------------------------------------------------
# True Box      : [0.781 0.271 0.148 0.137]
# Predicted Box : [0.78  0.281 0.161 0.136]
# IoU : 0.805
# Status : ✔ EXCELLENT
#
# Sample 116
# ------------------------------------------------------------
# True Box      : [0.35  0.723 0.16  0.18 ]
# Predicted Box : [0.352 0.732 0.165 0.161]
# IoU : 0.87
# Status : ✔ EXCELLENT
#
# Sample 117
# ------------------------------------------------------------
# True Box      : [0.145 0.742 0.109 0.18 ]
# Predicted Box : [0.134 0.755 0.116 0.141]
# IoU : 0.665
# Status : ➜ GOOD
#
# Sample 118
# ------------------------------------------------------------
# True Box      : [0.889 0.918 0.121 0.086]
# Predicted Box : [0.864 0.906 0.125 0.123]
# IoU : 0.487
# Status : ✖ WEAK
#
# Sample 119
# ------------------------------------------------------------
# True Box      : [0.195 0.129 0.109 0.086]
# Predicted Box : [0.187 0.119 0.109 0.101]
# IoU : 0.71
# Status : ➜ GOOD
#
# Sample 120
# ------------------------------------------------------------
# True Box      : [0.305 0.123 0.117 0.176]
# Predicted Box : [0.311 0.128 0.111 0.168]
# IoU : 0.843
# Status : ✔ EXCELLENT
#
# Sample 121
# ------------------------------------------------------------
# True Box      : [0.123 0.527 0.09  0.125]
# Predicted Box : [0.115 0.534 0.11  0.129]
# IoU : 0.742
# Status : ➜ GOOD
#
# Sample 122
# ------------------------------------------------------------
# True Box      : [0.309 0.775 0.18  0.184]
# Predicted Box : [0.303 0.787 0.177 0.174]
# IoU : 0.825
# Status : ✔ EXCELLENT
#
# Sample 123
# ------------------------------------------------------------
# True Box      : [0.268 0.451 0.16  0.191]
# Predicted Box : [0.263 0.454 0.162 0.167]
# IoU : 0.833
# Status : ✔ EXCELLENT
#
# Sample 124
# ------------------------------------------------------------
# True Box      : [0.322 0.762 0.184 0.094]
# Predicted Box : [0.329 0.761 0.182 0.089]
# IoU : 0.878
# Status : ✔ EXCELLENT
#
# Sample 125
# ------------------------------------------------------------
# True Box      : [0.887 0.463 0.172 0.09 ]
# Predicted Box : [0.871 0.47  0.164 0.109]
# IoU : 0.695
# Status : ➜ GOOD
#
# Sample 126
# ------------------------------------------------------------
# True Box      : [0.75  0.434 0.102 0.172]
# Predicted Box : [0.747 0.434 0.101 0.159]
# IoU : 0.874
# Status : ✔ EXCELLENT
#
# Sample 127
# ------------------------------------------------------------
# True Box      : [0.316 0.785 0.188 0.125]
# Predicted Box : [0.312 0.79  0.182 0.116]
# IoU : 0.878
# Status : ✔ EXCELLENT
#
# Sample 128
# ------------------------------------------------------------
# True Box      : [0.76  0.4   0.176 0.09 ]
# Predicted Box : [0.76  0.397 0.172 0.086]
# IoU : 0.914
# Status : ✔ EXCELLENT
#
# Sample 129
# ------------------------------------------------------------
# True Box      : [0.412 0.424 0.176 0.145]
# Predicted Box : [0.406 0.427 0.169 0.146]
# IoU : 0.892
# Status : ✔ EXCELLENT
#
# Sample 130
# ------------------------------------------------------------
# True Box      : [0.217 0.346 0.121 0.113]
# Predicted Box : [0.208 0.34  0.121 0.111]
# IoU : 0.784
# Status : ➜ GOOD
#
# Sample 131
# ------------------------------------------------------------
# True Box      : [0.617 0.799 0.172 0.105]
# Predicted Box : [0.61  0.808 0.162 0.094]
# IoU : 0.77
# Status : ➜ GOOD
#
# Sample 132
# ------------------------------------------------------------
# True Box      : [0.355 0.346 0.148 0.082]
# Predicted Box : [0.343 0.338 0.141 0.086]
# IoU : 0.721
# Status : ➜ GOOD
#
# Sample 133
# ------------------------------------------------------------
# True Box      : [0.246 0.908 0.094 0.082]
# Predicted Box : [0.244 0.912 0.102 0.08 ]
# IoU : 0.835
# Status : ✔ EXCELLENT
#
# Sample 134
# ------------------------------------------------------------
# True Box      : [0.148 0.703 0.125 0.102]
# Predicted Box : [0.141 0.711 0.136 0.092]
# IoU : 0.765
# Status : ➜ GOOD
#
# Sample 135
# ------------------------------------------------------------
# True Box      : [0.08  0.701 0.098 0.16 ]
# Predicted Box : [0.082 0.711 0.119 0.137]
# IoU : 0.72
# Status : ➜ GOOD
#
# Sample 136
# ------------------------------------------------------------
# True Box      : [0.898 0.574 0.102 0.18 ]
# Predicted Box : [0.907 0.572 0.103 0.156]
# IoU : 0.746
# Status : ➜ GOOD
#
# Sample 137
# ------------------------------------------------------------
# True Box      : [0.672 0.35  0.172 0.105]
# Predicted Box : [0.666 0.349 0.164 0.11 ]
# IoU : 0.894
# Status : ✔ EXCELLENT
#
# Sample 138
# ------------------------------------------------------------
# True Box      : [0.607 0.654 0.137 0.145]
# Predicted Box : [0.609 0.658 0.137 0.149]
# IoU : 0.932
# Status : ✔ EXCELLENT
#
# Sample 139
# ------------------------------------------------------------
# True Box      : [0.227 0.59  0.078 0.125]
# Predicted Box : [0.219 0.588 0.084 0.123]
# IoU : 0.816
# Status : ✔ EXCELLENT
#
# Sample 140
# ------------------------------------------------------------
# True Box      : [0.844 0.605 0.125 0.094]
# Predicted Box : [0.855 0.608 0.124 0.112]
# IoU : 0.708
# Status : ➜ GOOD
#
# Sample 141
# ------------------------------------------------------------
# True Box      : [0.404 0.645 0.184 0.18 ]
# Predicted Box : [0.395 0.652 0.165 0.155]
# IoU : 0.775
# Status : ➜ GOOD
#
# Sample 142
# ------------------------------------------------------------
# True Box      : [0.734 0.613 0.109 0.156]
# Predicted Box : [0.732 0.622 0.108 0.156]
# IoU : 0.862
# Status : ✔ EXCELLENT
#
# Sample 143
# ------------------------------------------------------------
# True Box      : [0.52  0.908 0.156 0.137]
# Predicted Box : [0.516 0.893 0.151 0.138]
# IoU : 0.767
# Status : ➜ GOOD
#
# Sample 144
# ------------------------------------------------------------
# True Box      : [0.58  0.363 0.184 0.141]
# Predicted Box : [0.585 0.358 0.182 0.131]
# IoU : 0.873
# Status : ✔ EXCELLENT
#
# Sample 145
# ------------------------------------------------------------
# True Box      : [0.789 0.434 0.125 0.109]
# Predicted Box : [0.77  0.436 0.129 0.107]
# IoU : 0.717
# Status : ➜ GOOD
#
# Sample 146
# ------------------------------------------------------------
# True Box      : [0.521 0.32  0.098 0.117]
# Predicted Box : [0.529 0.319 0.099 0.101]
# IoU : 0.751
# Status : ➜ GOOD
#
# Sample 147
# ------------------------------------------------------------
# True Box      : [0.775 0.32  0.121 0.109]
# Predicted Box : [0.766 0.322 0.128 0.121]
# IoU : 0.78
# Status : ➜ GOOD
#
# Sample 148
# ------------------------------------------------------------
# True Box      : [0.232 0.668 0.129 0.164]
# Predicted Box : [0.231 0.672 0.118 0.158]
# IoU : 0.871
# Status : ✔ EXCELLENT
#
# Sample 149
# ------------------------------------------------------------
# True Box      : [0.527 0.266 0.125 0.156]
# Predicted Box : [0.532 0.259 0.127 0.148]
# IoU : 0.862
# Status : ✔ EXCELLENT
#
# Sample 150
# ------------------------------------------------------------
# True Box      : [0.426 0.236 0.18  0.184]
# Predicted Box : [0.425 0.232 0.175 0.172]
# IoU : 0.912
# Status : ✔ EXCELLENT
#
# Sample 151
# ------------------------------------------------------------
# True Box      : [0.074 0.721 0.102 0.113]
# Predicted Box : [0.075 0.725 0.113 0.125]
# IoU : 0.815
# Status : ✔ EXCELLENT
#
# Sample 152
# ------------------------------------------------------------
# True Box      : [0.553 0.672 0.105 0.133]
# Predicted Box : [0.555 0.667 0.11  0.139]
# IoU : 0.896
# Status : ✔ EXCELLENT
#
# Sample 153
# ------------------------------------------------------------
# True Box      : [0.23  0.676 0.148 0.148]
# Predicted Box : [0.23  0.683 0.139 0.136]
# IoU : 0.851
# Status : ✔ EXCELLENT
#
# Sample 154
# ------------------------------------------------------------
# True Box      : [0.922 0.23  0.078 0.188]
# Predicted Box : [0.933 0.239 0.082 0.159]
# IoU : 0.659
# Status : ➜ GOOD
#
# Sample 155
# ------------------------------------------------------------
# True Box      : [0.354 0.537 0.16  0.129]
# Predicted Box : [0.352 0.545 0.161 0.111]
# IoU : 0.85
# Status : ✔ EXCELLENT
#
# Sample 156
# ------------------------------------------------------------
# True Box      : [0.393 0.889 0.129 0.168]
# Predicted Box : [0.391 0.868 0.139 0.161]
# IoU : 0.727
# Status : ➜ GOOD
#
# Sample 157
# ------------------------------------------------------------
# True Box      : [0.736 0.84  0.176 0.109]
# Predicted Box : [0.734 0.845 0.167 0.116]
# IoU : 0.865
# Status : ✔ EXCELLENT
#
# Sample 158
# ------------------------------------------------------------
# True Box      : [0.152 0.301 0.109 0.078]
# Predicted Box : [0.148 0.302 0.11  0.079]
# IoU : 0.892
# Status : ✔ EXCELLENT
#
# Sample 159
# ------------------------------------------------------------
# True Box      : [0.73  0.889 0.156 0.16 ]
# Predicted Box : [0.718 0.868 0.166 0.148]
# IoU : 0.661
# Status : ➜ GOOD
#
# Sample 160
# ------------------------------------------------------------
# True Box      : [0.453 0.125 0.133 0.109]
# Predicted Box : [0.451 0.124 0.143 0.11 ]
# IoU : 0.905
# Status : ✔ EXCELLENT
#
# Sample 161
# ------------------------------------------------------------
# True Box      : [0.195 0.865 0.18  0.121]
# Predicted Box : [0.193 0.879 0.156 0.102]
# IoU : 0.682
# Status : ➜ GOOD
#
# Sample 162
# ------------------------------------------------------------
# True Box      : [0.621 0.213 0.102 0.105]
# Predicted Box : [0.615 0.219 0.104 0.095]
# IoU : 0.788
# Status : ➜ GOOD
#
# Sample 163
# ------------------------------------------------------------
# True Box      : [0.314 0.543 0.145 0.117]
# Predicted Box : [0.313 0.551 0.141 0.107]
# IoU : 0.85
# Status : ✔ EXCELLENT
#
# Sample 164
# ------------------------------------------------------------
# True Box      : [0.227 0.35  0.086 0.145]
# Predicted Box : [0.222 0.342 0.1   0.14 ]
# IoU : 0.783
# Status : ➜ GOOD
#
# Sample 165
# ------------------------------------------------------------
# True Box      : [0.67  0.523 0.191 0.094]
# Predicted Box : [0.652 0.518 0.17  0.102]
# IoU : 0.75
# Status : ➜ GOOD
#
# Sample 166
# ------------------------------------------------------------
# True Box      : [0.283 0.682 0.145 0.113]
# Predicted Box : [0.29  0.676 0.152 0.107]
# IoU : 0.825
# Status : ✔ EXCELLENT
#
# Sample 167
# ------------------------------------------------------------
# True Box      : [0.682 0.441 0.121 0.188]
# Predicted Box : [0.675 0.442 0.113 0.173]
# IoU : 0.825
# Status : ✔ EXCELLENT
#
# Sample 168
# ------------------------------------------------------------
# True Box      : [0.332 0.453 0.172 0.117]
# Predicted Box : [0.333 0.449 0.16  0.11 ]
# IoU : 0.866
# Status : ✔ EXCELLENT
#
# Sample 169
# ------------------------------------------------------------
# True Box      : [0.387 0.127 0.164 0.184]
# Predicted Box : [0.384 0.14  0.168 0.161]
# IoU : 0.836
# Status : ✔ EXCELLENT
#
# Sample 170
# ------------------------------------------------------------
# True Box      : [0.797 0.688 0.156 0.141]
# Predicted Box : [0.786 0.697 0.161 0.139]
# IoU : 0.763
# Status : ➜ GOOD
#
# Sample 171
# ------------------------------------------------------------
# True Box      : [0.438 0.482 0.133 0.152]
# Predicted Box : [0.444 0.479 0.138 0.142]
# IoU : 0.853
# Status : ✔ EXCELLENT
#
# Sample 172
# ------------------------------------------------------------
# True Box      : [0.676 0.199 0.133 0.133]
# Predicted Box : [0.669 0.201 0.136 0.126]
# IoU : 0.856
# Status : ✔ EXCELLENT
#
# Sample 173
# ------------------------------------------------------------
# True Box      : [0.783 0.49  0.16  0.145]
# Predicted Box : [0.773 0.49  0.175 0.14 ]
# IoU : 0.864
# Status : ✔ EXCELLENT
#
# Sample 174
# ------------------------------------------------------------
# True Box      : [0.506 0.084 0.184 0.105]
# Predicted Box : [0.51  0.085 0.165 0.102]
# IoU : 0.871
# Status : ✔ EXCELLENT
#
# Sample 175
# ------------------------------------------------------------
# True Box      : [0.553 0.17  0.152 0.152]
# Predicted Box : [0.556 0.174 0.146 0.15 ]
# IoU : 0.905
# Status : ✔ EXCELLENT
#
# Sample 176
# ------------------------------------------------------------
# True Box      : [0.658 0.486 0.09  0.121]
# Predicted Box : [0.64  0.482 0.097 0.117]
# IoU : 0.637
# Status : ➜ GOOD
#
# Sample 177
# ------------------------------------------------------------
# True Box      : [0.438 0.184 0.172 0.164]
# Predicted Box : [0.431 0.187 0.174 0.16 ]
# IoU : 0.89
# Status : ✔ EXCELLENT
#
# Sample 178
# ------------------------------------------------------------
# True Box      : [0.234 0.752 0.078 0.168]
# Predicted Box : [0.23  0.759 0.088 0.167]
# IoU : 0.819
# Status : ✔ EXCELLENT
#
# Sample 179
# ------------------------------------------------------------
# True Box      : [0.818 0.695 0.145 0.102]
# Predicted Box : [0.822 0.708 0.135 0.105]
# IoU : 0.737
# Status : ➜ GOOD
#
# Sample 180
# ------------------------------------------------------------
# True Box      : [0.736 0.24  0.09  0.129]
# Predicted Box : [0.721 0.25  0.107 0.136]
# IoU : 0.642
# Status : ➜ GOOD
#
# Sample 181
# ------------------------------------------------------------
# True Box      : [0.805 0.184 0.188 0.164]
# Predicted Box : [0.805 0.187 0.187 0.154]
# IoU : 0.936
# Status : ✔ EXCELLENT
#
# Sample 182
# ------------------------------------------------------------
# True Box      : [0.275 0.768 0.121 0.129]
# Predicted Box : [0.276 0.766 0.127 0.122]
# IoU : 0.908
# Status : ✔ EXCELLENT
#
# Sample 183
# ------------------------------------------------------------
# True Box      : [0.867 0.598 0.094 0.156]
# Predicted Box : [0.871 0.596 0.097 0.179]
# IoU : 0.806
# Status : ✔ EXCELLENT
#
# Sample 184
# ------------------------------------------------------------
# True Box      : [0.596 0.432 0.113 0.105]
# Predicted Box : [0.591 0.431 0.11  0.106]
# IoU : 0.914
# Status : ✔ EXCELLENT
#
# Sample 185
# ------------------------------------------------------------
# True Box      : [0.553 0.203 0.082 0.188]
# Predicted Box : [0.552 0.204 0.083 0.166]
# IoU : 0.87
# Status : ✔ EXCELLENT
#
# Sample 186
# ------------------------------------------------------------
# True Box      : [0.174 0.439 0.121 0.184]
# Predicted Box : [0.176 0.433 0.104 0.171]
# IoU : 0.801
# Status : ✔ EXCELLENT
#
# Sample 187
# ------------------------------------------------------------
# True Box      : [0.156 0.285 0.172 0.133]
# Predicted Box : [0.152 0.295 0.173 0.127]
# IoU : 0.824
# Status : ✔ EXCELLENT
#
# Sample 188
# ------------------------------------------------------------
# True Box      : [0.289 0.854 0.086 0.137]
# Predicted Box : [0.288 0.847 0.097 0.13 ]
# IoU : 0.811
# Status : ✔ EXCELLENT
#
# Sample 189
# ------------------------------------------------------------
# True Box      : [0.869 0.596 0.121 0.121]
# Predicted Box : [0.87  0.594 0.122 0.147]
# IoU : 0.815
# Status : ✔ EXCELLENT
#
# Sample 190
# ------------------------------------------------------------
# True Box      : [0.322 0.25  0.113 0.078]
# Predicted Box : [0.314 0.24  0.099 0.089]
# IoU : 0.683
# Status : ➜ GOOD
#
# Sample 191
# ------------------------------------------------------------
# True Box      : [0.549 0.238 0.105 0.18 ]
# Predicted Box : [0.556 0.237 0.092 0.158]
# IoU : 0.756
# Status : ➜ GOOD
#
# Sample 192
# ------------------------------------------------------------
# True Box      : [0.758 0.17  0.117 0.137]
# Predicted Box : [0.75  0.177 0.125 0.13 ]
# IoU : 0.798
# Status : ➜ GOOD
#
# Sample 193
# ------------------------------------------------------------
# True Box      : [0.689 0.535 0.09  0.18 ]
# Predicted Box : [0.689 0.54  0.082 0.169]
# IoU : 0.854
# Status : ✔ EXCELLENT
#
# Sample 194
# ------------------------------------------------------------
# True Box      : [0.602 0.623 0.164 0.137]
# Predicted Box : [0.597 0.618 0.166 0.127]
# IoU : 0.877
# Status : ✔ EXCELLENT
#
# Sample 195
# ------------------------------------------------------------
# True Box      : [0.479 0.289 0.184 0.133]
# Predicted Box : [0.489 0.287 0.175 0.123]
# IoU : 0.828
# Status : ✔ EXCELLENT
#
# Sample 196
# ------------------------------------------------------------
# True Box      : [0.477 0.627 0.094 0.184]
# Predicted Box : [0.477 0.632 0.095 0.172]
# IoU : 0.921
# Status : ✔ EXCELLENT
#
# Sample 197
# ------------------------------------------------------------
# True Box      : [0.883 0.588 0.117 0.168]
# Predicted Box : [0.884 0.587 0.112 0.173]
# IoU : 0.93
# Status : ✔ EXCELLENT
#
# Sample 198
# ------------------------------------------------------------
# True Box      : [0.363 0.178 0.078 0.113]
# Predicted Box : [0.36  0.184 0.083 0.107]
# IoU : 0.837
# Status : ✔ EXCELLENT
#
# Sample 199
# ------------------------------------------------------------
# True Box      : [0.592 0.125 0.113 0.164]
# Predicted Box : [0.591 0.136 0.122 0.16 ]
# IoU : 0.812
# Status : ✔ EXCELLENT
#
# Sample 200
# ------------------------------------------------------------
# True Box      : [0.35  0.879 0.09  0.125]
# Predicted Box : [0.336 0.878 0.124 0.119]
# IoU : 0.7
# Status : ➜ GOOD

# %%
print("="*80)
print("FINAL SUMMARY")
print("="*80)
print("Total Samples :", len(ious))
print(f"Excellent (>=0.80) : {excellent} -> {(excellent/len(ious))*100:.2f}%")
print(f"Good (>=0.60) : {good} -> {(good/len(ious))*100:.2f}%")
print(f"Weak (<0.60) : {weak} -> {(weak/len(ious))*100:.2f}%")
print("Average IoU :", round(np.mean(ious),3))
# Out:
# ================================================================================
# FINAL SUMMARY
# ================================================================================
# Total Samples : 200
# Excellent (>=0.80) : 134 -> 67.00%
# Good (>=0.60) : 63 -> 31.50%
# Weak (<0.60) : 3 -> 1.50%
# Average IoU : 0.819
