# %% [markdown]
# # IMAGE SEGMENTATION USING U-Net CNN (circle)

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import numpy as np  # numerical operations
import cv2  # image processing
import matplotlib.pyplot as plt  # visualization
from sklearn.model_selection import train_test_split  # dataset split
from tensorflow.keras.callbacks import EarlyStopping  # early stopping

# %%
from tensorflow.keras.layers import (
    Input,          # input layer
    Conv2D,         # convolution layer
    MaxPooling2D,   # downsampling
    UpSampling2D,   # upsampling
    Concatenate     # skip connections
)

from tensorflow.keras.models import Model  # U-Net model

# %% [markdown]
# ## CONFIGURATION

# %%
Image_Size = 256  # input image size
sample = 1000

# %% [markdown]
# ## DATASET

# %% [markdown]
# ### CREATE

# %%
def create_dataset(samples=sample):

    images = []
    masks = []

    for _ in range(samples):

        img = np.zeros((Image_Size, Image_Size, 3),dtype=np.uint8)
        mask = np.zeros((Image_Size, Image_Size, 1),dtype=np.uint8)

        r = np.random.randint(10,20)
        x = np.random.randint(r+5, Image_Size-r-5)
        y = np.random.randint(r+5, Image_Size-r-5)

        cv2.circle(img,(x,y), r, (255,255,255), -1)
        cv2.circle(mask,(x,y), r, 255, -1)

        images.append(img)
        masks.append(mask)

    return np.array(images), np.array(masks)

# %% [markdown]
# ### GENERATE

# %%
X, y = create_dataset(sample)

print("=" * 60)
print("DATASET CREATED")
print("=" * 60)

print("Images Shape :", X.shape)
print("Labels/Masks :", y.shape)
# Out:
# ============================================================
# DATASET CREATED
# ============================================================
# Images Shape : (1000, 256, 256, 3)
# Labels/Masks : (1000, 256, 256, 1)

# %% [markdown]
# ### NORMALIZATION

# %%
X = X.astype("float32") / 255.0
y = y.astype("float32") / 255.0

# %% [markdown]
# ### TRAIN TEST SPLIT

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42, shuffle=True)
print("=" * 60)
print("TRAIN / TEST SPLIT")
print("=" * 60)
print("Training Images :", X_train.shape)
print("Testing Images  :", X_test.shape)
print("Training Labels :", y_train.shape)
print("Testing Labels  :", y_test.shape)
# Out:
# ============================================================
# TRAIN / TEST SPLIT
# ============================================================
# Training Images : (800, 256, 256, 3)
# Testing Images  : (200, 256, 256, 3)
# Training Labels : (800, 256, 256, 1)
# Testing Labels  : (200, 256, 256, 1)

# %% [markdown]
# ## MODEL

# %% [markdown]
# ### BUILD

# %%
def conv_block(x, filters):
    x = Conv2D(filters, (3,3), padding="same", activation="relu")(x)
    x = Conv2D(filters, (3,3), padding="same", activation="relu")(x)
    return x

inputs = Input(shape=(Image_Size, Image_Size, 3))

# ENCODER

c1 = conv_block(inputs, 32)
p1 = MaxPooling2D()(c1)

c2 = conv_block(p1, 64)
p2 = MaxPooling2D()(c2)

c3 = conv_block(p2, 128)
p3 = MaxPooling2D()(c3)

# BOTTLENECK

bn = conv_block(p3, 256)

# DECODER

u1 = UpSampling2D()(bn)
concat1 = Concatenate()([u1, c3])
c4 = conv_block(concat1, 128)

u2 = UpSampling2D()(c4)
concat2 = Concatenate()([u2, c2])
c5 = conv_block(concat2, 64)

u3 = UpSampling2D()(c5)
concat3 = Concatenate()([u3, c1])
c6 = conv_block(concat3, 32)

# OUTPUT LAYER

outputs = Conv2D(
    1,
    (1,1),
    activation="sigmoid"
)(c6)

model = Model(inputs, outputs)

# %% [markdown]
# ### SUMMARY

# %%
print("="*60)
print("MODEL SUMMARY")
print("="*60)

model.summary()
# Out:
# ============================================================
# MODEL SUMMARY
# ============================================================
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 256, 256,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 64,    │          0 │ conv2d_7[0][0]    │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 384)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │    442,496 │ concatenate[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │    147,584 │ conv2d_8[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 128,  │          0 │ conv2d_9[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │    110,656 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_10[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 256, 256,  │          0 │ conv2d_11[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 256, 256,  │     27,680 │ concatenate_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │      9,248 │ conv2d_12[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │         33 │ conv2d_13[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,946,881 (7.43 MB)
#  Trainable params: 1,946,881 (7.43 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### COMPILE

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %% [markdown]
# ### EARLY STOPPING

# %%
early_stop = EarlyStopping(
    monitor="val_loss",  # monitor validation loss
    patience=3,  # stop if no improvement
    restore_best_weights=True  # keep best model
)

# %% [markdown]
# ### TRAIN

# %%
history = model.fit(
    X_train, y_train,
    validation_split=0.20,
    epochs=20,
    batch_size=16,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 56s 465ms/step - accuracy: 0.9939 - loss: 0.0884 - val_accuracy: 0.9997 - val_loss: 8.9137e-04
# Epoch 2/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 0.9998 - loss: 5.5717e-04 - val_accuracy: 0.9999 - val_loss: 3.6912e-04
# Epoch 3/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 10s 260ms/step - accuracy: 0.9999 - loss: 3.0087e-04 - val_accuracy: 0.9999 - val_loss: 2.2685e-04
# Epoch 4/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 266ms/step - accuracy: 0.9999 - loss: 2.5144e-04 - val_accuracy: 0.9999 - val_loss: 2.8017e-04
# Epoch 5/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - accuracy: 1.0000 - loss: 1.6926e-04 - val_accuracy: 1.0000 - val_loss: 1.1294e-04
# Epoch 6/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 275ms/step - accuracy: 1.0000 - loss: 8.5465e-05 - val_accuracy: 1.0000 - val_loss: 6.3372e-05
# Epoch 7/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 282ms/step - accuracy: 1.0000 - loss: 4.5855e-05 - val_accuracy: 1.0000 - val_loss: 3.4751e-05
# Epoch 8/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 289ms/step - accuracy: 1.0000 - loss: 2.4501e-05 - val_accuracy: 1.0000 - val_loss: 1.7676e-05
# Epoch 9/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 285ms/step - accuracy: 1.0000 - loss: 1.3834e-05 - val_accuracy: 1.0000 - val_loss: 9.8624e-06
# Epoch 10/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 279ms/step - accuracy: 1.0000 - loss: 7.6858e-06 - val_accuracy: 1.0000 - val_loss: 6.5364e-06
# Epoch 11/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 275ms/step - accuracy: 1.0000 - loss: 5.1630e-06 - val_accuracy: 1.0000 - val_loss: 4.5147e-06
# Epoch 12/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 275ms/step - accuracy: 1.0000 - loss: 3.4591e-06 - val_accuracy: 1.0000 - val_loss: 4.3300e-06
# Epoch 13/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 21s 274ms/step - accuracy: 1.0000 - loss: 2.7394e-06 - val_accuracy: 1.0000 - val_loss: 3.6570e-06
# Epoch 14/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 283ms/step - accuracy: 1.0000 - loss: 1.9601e-06 - val_accuracy: 1.0000 - val_loss: 1.8873e-06
# Epoch 15/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 12s 293ms/step - accuracy: 1.0000 - loss: 1.4898e-06 - val_accuracy: 1.0000 - val_loss: 1.5780e-06
# Epoch 16/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 286ms/step - accuracy: 1.0000 - loss: 1.2402e-06 - val_accuracy: 1.0000 - val_loss: 1.2400e-06
# Epoch 17/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 280ms/step - accuracy: 1.0000 - loss: 9.6650e-07 - val_accuracy: 1.0000 - val_loss: 1.0061e-06
# Epoch 18/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - accuracy: 1.0000 - loss: 8.2084e-07 - val_accuracy: 1.0000 - val_loss: 1.0034e-06
# Epoch 19/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 274ms/step - accuracy: 1.0000 - loss: 7.0719e-07 - val_accuracy: 1.0000 - val_loss: 7.1835e-07
# Epoch 20/20
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 11s 276ms/step - accuracy: 1.0000 - loss: 5.9873e-07 - val_accuracy: 1.0000 - val_loss: 6.8690e-07

# %% [markdown]
# ## LOSS PLOT

# %%
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'], label="Training Loss")  # training loss
plt.plot(history.history['val_loss'], label="Validation Loss")  # validation loss
plt.title("Training vs Validation Loss")  # title
plt.xlabel("Epoch")  # x-axis
plt.ylabel("Loss")  # y-axis
plt.title("Training vs Validation Loss")
plt.legend()  # legend
plt.grid(True)
plt.show()  # display graph

# %%
# U-net
test_loss, test_acc = model.evaluate(X_test, y_test)
print("\nTest Loss :", round(test_loss,4))
print(f"Test Accuracy : {test_acc:.2%}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - accuracy: 1.0000 - loss: 5.4099e-07
#
# Test Loss : 0.0
# Test Accuracy : 100.00%

# %% [markdown]
# ## IoU FUNCTION

# %%
def IoU(mask1, mask2):

    mask1 = mask1.astype(bool)
    mask2 = mask2.astype(bool)

    intersection = np.logical_and(mask1, mask2).sum()
    union = np.logical_or(mask1, mask2).sum()

    return intersection / (union + 1e-6)

# %% [markdown]
# ## VISUALIZATION (TRUE VS PREDICTED)

# %%
def draw_contours(img, mask, color):

    mask = (mask > 0.5).astype(np.uint8)
    contours, _ = cv2.findContours(mask.squeeze(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cv2.drawContours(img, contours, -1, color, 2)

# %%
preds = model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 332ms/step

# %%
plt.figure(figsize=(20,20))

for i in range(min(len(X_test),20)):

    img = (X_test[i] * 255).astype(np.uint8).copy()

    # U-Net
    iou = IoU((preds[i] > 0.5).astype(np.uint8), (y_test[i] > 0.5).astype(np.uint8))
    draw_contours(img, y_test[i], (255,0,255))

    if iou >= 0.80:
        pred_color = (0,255,0)
        status = "EXCELLENT"
    elif iou >= 0.60:
        pred_color = (255,0,0)
        status = "GOOD"
    else:
        pred_color = (0,0,255)
        status = "WEAK"

    # U-Net
    draw_contours(img, preds[i], pred_color)

    plt.subplot(10,10,i+1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(f"S{i+1}\n{status}\nIoU={iou:.2f}", fontsize=8)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## REPORT

# %%
ious = []

# %%
for i in range(len(preds)):
    pred_mask = (preds[i] > 0.5).astype(np.uint8)
    true_mask = (y_test[i] > 0.5).astype(np.uint8)
    ious.append(IoU(pred_mask, true_mask))

# %%
excellent = 0
good = 0
weak = 0

for iou in ious:
    if iou >= 0.80:
        excellent += 1
    elif iou >= 0.60:
        good += 1
    else:
        weak += 1

print("="*80)

# U-net
print("SEGMENTATION REPORT")

print("="*80)

for i in range(len(preds)):
    iou = ious[i]
    if iou >= 0.80:
        status = "✔ EXCELLENT"
    elif iou >= 0.60:
        status = "➜ GOOD"
    else:
        status = "✖ WEAK"
    print(f"\nSample {i+1}")
    print("-"*60)

    # U-Net
    pred_mask = (preds[i] > 0.5).astype(np.uint8)
    true_mask = (y_test[i] > 0.5).astype(np.uint8)
    print("True Pixels      :",int(np.sum(true_mask)))
    print("Predicted Pixels :",int(np.sum(pred_mask)))

    print("IoU :", round(iou,3))
    print("Status :", status)
# Out:
# ================================================================================
# SEGMENTATION REPORT
# ================================================================================
#
# Sample 1
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 2
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 3
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 4
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 5
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 6
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 7
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 8
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 9
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 10
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 11
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 12
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 13
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 14
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 15
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 16
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 17
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 18
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 19
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 20
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 21
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 22
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 23
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 24
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 25
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 26
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 27
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 28
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 29
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 30
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 31
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 32
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 33
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 34
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 35
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 36
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 37
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 38
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 39
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 40
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 41
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 42
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 43
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 44
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 45
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 46
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 47
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 48
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 49
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 50
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 51
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 52
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 53
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 54
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 55
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 56
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 57
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 58
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 59
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 60
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 61
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 62
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 63
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 64
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 65
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 66
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 67
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 68
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 69
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 70
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 71
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 72
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 73
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 74
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 75
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 76
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 77
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 78
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 79
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 80
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 81
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 82
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 83
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 84
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 85
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 86
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 87
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 88
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 89
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 90
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 91
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 92
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 93
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 94
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 95
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 96
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 97
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 98
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 99
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 100
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 101
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 102
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 103
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 104
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 105
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 106
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 107
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 108
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 109
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 110
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 111
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 112
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 113
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 114
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 115
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 116
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 117
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 118
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 119
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 120
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 121
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 122
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 123
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 124
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 125
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 126
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 127
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 128
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 129
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 130
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 131
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 132
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 133
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 134
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 135
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 136
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 137
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 138
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 139
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 140
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 141
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 142
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 143
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 144
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 145
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 146
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 147
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 148
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 149
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 150
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 151
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 152
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 153
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 154
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 155
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 156
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 157
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 158
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 159
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 160
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 161
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 162
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 163
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 164
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 165
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 166
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 167
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 168
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 169
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 170
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 171
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 172
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 173
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 174
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 175
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 176
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 177
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 178
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 179
# ------------------------------------------------------------
# True Pixels      : 1009
# Predicted Pixels : 1009
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 180
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 181
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 182
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 183
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 184
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 185
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 186
# ------------------------------------------------------------
# True Pixels      : 377
# Predicted Pixels : 377
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 187
# ------------------------------------------------------------
# True Pixels      : 613
# Predicted Pixels : 613
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 188
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 189
# ------------------------------------------------------------
# True Pixels      : 1129
# Predicted Pixels : 1129
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 190
# ------------------------------------------------------------
# True Pixels      : 901
# Predicted Pixels : 901
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 191
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 192
# ------------------------------------------------------------
# True Pixels      : 441
# Predicted Pixels : 441
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 193
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 194
# ------------------------------------------------------------
# True Pixels      : 709
# Predicted Pixels : 709
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 195
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 196
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 197
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 198
# ------------------------------------------------------------
# True Pixels      : 317
# Predicted Pixels : 317
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 199
# ------------------------------------------------------------
# True Pixels      : 529
# Predicted Pixels : 529
# IoU : 1.0
# Status : ✔ EXCELLENT
#
# Sample 200
# ------------------------------------------------------------
# True Pixels      : 797
# Predicted Pixels : 797
# IoU : 1.0
# Status : ✔ EXCELLENT

# %%
print("="*80)
print("FINAL SUMMARY")
print("="*80)
print("Total Samples :", len(ious))
print(f"Excellent (>=0.80) : {excellent} -> {(excellent/len(ious))*100:.2f}%")
print(f"Good (>=0.60) : {good} -> {(good/len(ious))*100:.2f}%")
print(f"Weak (<0.60) : {weak} -> {(weak/len(ious))*100:.2f}%")
print("Average IoU :", round(np.mean(ious),3))
# Out:
# ================================================================================
# FINAL SUMMARY
# ================================================================================
# Total Samples : 200
# Excellent (>=0.80) : 200 -> 100.00%
# Good (>=0.60) : 0 -> 0.00%
# Weak (<0.60) : 0 -> 0.00%
# Average IoU : 1.0
